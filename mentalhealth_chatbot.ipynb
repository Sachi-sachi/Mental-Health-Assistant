# %%
# !pip install -U -r requirements.txt
# Out:
# Requirement already satisfied: langsmith in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from -r requirements.txt (line 1)) (0.3.42)
# Requirement already satisfied: langchain in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from -r requirements.txt (line 2)) (0.3.25)
# Requirement already satisfied: langchain_community in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from -r requirements.txt (line 3)) (0.3.23)
# Requirement already satisfied: langchain-groq in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from -r requirements.txt (line 4)) (0.3.2)
# Requirement already satisfied: groq in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from -r requirements.txt (line 5)) (0.24.0)
# Requirement already satisfied: streamlit in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from -r requirements.txt (line 6)) (1.45.0)
# Requirement already satisfied: langchain_huggingface in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from -r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: cassio in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from -r requirements.txt (line 8)) (0.1.10)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langsmith->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langsmith->-r requirements.txt (line 1)) (3.10.16)
# Requirement already satisfied: packaging>=23.2 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langsmith->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langsmith->-r requirements.txt (line 1)) (2.11.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langsmith->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langsmith->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langsmith->-r requirements.txt (line 1)) (0.23.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain->-r requirements.txt (line 2)) (0.3.59)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain->-r requirements.txt (line 2)) (0.3.8)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain->-r requirements.txt (line 2)) (2.0.40)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain->-r requirements.txt (line 2)) (4.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain_community->-r requirements.txt (line 3)) (3.11.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain_community->-r requirements.txt (line 3)) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain_community->-r requirements.txt (line 3)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain_community->-r requirements.txt (line 3)) (2.8.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain_community->-r requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain_community->-r requirements.txt (line 3)) (2.2.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from groq->-r requirements.txt (line 5)) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from groq->-r requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from groq->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from groq->-r requirements.txt (line 5)) (4.13.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from streamlit->-r requirements.txt (line 6)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from streamlit->-r requirements.txt (line 6)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from streamlit->-r requirements.txt (line 6)) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from streamlit->-r requirements.txt (line 6)) (8.1.8)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from streamlit->-r requirements.txt (line 6)) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from streamlit->-r requirements.txt (line 6)) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from streamlit->-r requirements.txt (line 6)) (5.29.4)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from streamlit->-r requirements.txt (line 6)) (19.0.1)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from streamlit->-r requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from streamlit->-r requirements.txt (line 6)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from streamlit->-r requirements.txt (line 6)) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from streamlit->-r requirements.txt (line 6)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from streamlit->-r requirements.txt (line 6)) (6.4.2)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain_huggingface->-r requirements.txt (line 7)) (0.21.1)
# Requirement already satisfied: transformers>=4.39.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain_huggingface->-r requirements.txt (line 7)) (4.50.3)
# Requirement already satisfied: sentence-transformers>=2.6.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain_huggingface->-r requirements.txt (line 7)) (4.0.1)
# Requirement already satisfied: huggingface-hub>=0.30.2 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain_huggingface->-r requirements.txt (line 7)) (0.31.1)
# Requirement already satisfied: cassandra-driver<4.0.0,>=3.28.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from cassio->-r requirements.txt (line 8)) (3.29.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 3)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 3)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 3)) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 3)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 3)) (1.18.3)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 6)) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 6)) (1.32.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from anyio<5,>=3.5.0->groq->-r requirements.txt (line 5)) (1.2.2)
# Requirement already satisfied: idna>=2.8 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from anyio<5,>=3.5.0->groq->-r requirements.txt (line 5)) (3.10)
# Requirement already satisfied: geomet<0.3,>=0.1 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from cassandra-driver<4.0.0,>=3.28.0->cassio->-r requirements.txt (line 8)) (0.2.1.post1)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from click<9,>=7.0->streamlit->-r requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 3)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 6)) (4.0.12)
# Requirement already satisfied: certifi in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from httpx<1,>=0.23.0->langsmith->-r requirements.txt (line 1)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from httpx<1,>=0.23.0->langsmith->-r requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: filelock in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from huggingface-hub>=0.30.2->langchain_huggingface->-r requirements.txt (line 7)) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from huggingface-hub>=0.30.2->langchain_huggingface->-r requirements.txt (line 7)) (2025.3.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from huggingface-hub>=0.30.2->langchain_huggingface->-r requirements.txt (line 7)) (4.67.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain->-r requirements.txt (line 2)) (1.33)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from pydantic<3,>=1->langsmith->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from pydantic<3,>=1->langsmith->-r requirements.txt (line 1)) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from pydantic<3,>=1->langsmith->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community->-r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from requests<3,>=2->langsmith->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from requests<3,>=2->langsmith->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface->-r requirements.txt (line 7)) (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface->-r requirements.txt (line 7)) (1.6.1)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from sentence-transformers>=2.6.0->langchain_huggingface->-r requirements.txt (line 7)) (1.15.2)
# Requirement already satisfied: greenlet>=1 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain->-r requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from transformers>=4.39.0->langchain_huggingface->-r requirements.txt (line 7)) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from transformers>=4.39.0->langchain_huggingface->-r requirements.txt (line 7)) (0.5.3)
# Requirement already satisfied: six in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from geomet<0.3,>=0.1->cassandra-driver<4.0.0,>=3.28.0->cassio->-r requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 6)) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit->-r requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 6)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 6)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 6)) (0.24.0)
# Requirement already satisfied: networkx in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface->-r requirements.txt (line 7)) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface->-r requirements.txt (line 7)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface->-r requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell\anaconda3\envs\mentalhealth-chatbot\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface->-r requirements.txt (line 7)) (3.6.0)

# %%
import cassandra.cluster
print("Cassandra driver loaded successfully!")
# Out:
# Cassandra driver loaded successfully!

# %%
import os
import getpass

os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")
os.environ["HF_TOKEN"] = getpass.getpass("Enter your HF API key: ")
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass("Enter your Langchain API key: ")
# Out:
# Enter your Groq API key:  ········
# Enter your HF API key:  ········
# Enter your Langchain API key:  ········

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama3-8b-8192",
    temperature=0,
    max_tokens=1000,
    timeout=None,
    # other params...
)
llm
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x000001BC5D2CE1D0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001BC5D2CF640>, model_name='llama3-8b-8192', temperature=1e-08, model_kwargs={}, groq_api_key=SecretStr('**********'), max_tokens=1000)

# %%
import csv
import json
import uuid
import cassio  # Using cassio for AstraDB connection
import pandas as pd
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_groq import ChatGroq

# AstraDB connection details
ASTRA_DB_APPLICATION_TOKEN =  getpass.getpass("Enter your Astra DB Token: ")
ASTRA_DB_ID =  getpass.getpass("Enter your Astra DB ID: ")


# Initialize AstraDB connection with Cassio
cassio.init(
    token=ASTRA_DB_APPLICATION_TOKEN,
    database_id=ASTRA_DB_ID
)

# Embeddings setup
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# ChatGroq LLM setup
llm = ChatGroq(
    model="llama3-8b-8192",
    temperature=0,
    max_tokens=4000,
    timeout=None
)
# Out:
# Enter your Astra DB Token:  ········
# Enter your Astra DB ID:  ········

# %% [markdown]
# Entering data in the Vector DB for RAG

# %%
from langchain.vectorstores.cassandra import Cassandra
from langchain.indexes.vectorstore import VectorStoreIndexWrapper
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.schema import Document
import cassio

# Create Cassandra vector store
astra_vector_store = Cassandra(
    embedding=embeddings,
    session=None,
    table_name="Projekt",
    keyspace=None
)

def process_csv(file_path, context_column, response_column):
    df = pd.read_csv(file_path)
    docs = []
    for _, row in df.iterrows():
        content = f"Context: {row[context_column]}\nResponse: {row[response_column]}"
        metadata = {"source": file_path, "type": "csv"}
        docs.append(Document(page_content=content, metadata=metadata))
    return docs

def process_json(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
    docs = []
    for item in data:
        content = f"Question: {item['question']}\nAnswer: {item['answer']}\nTopic: {item['topic']}"
        metadata = {"source": file_path, "type": "json", "topic": item['topic']}
        docs.append(Document(page_content=content, metadata=metadata))
    return docs

# Process and add documents
docs = []
docs.extend(process_csv('amod.csv', 'Context', 'Response'))
docs.extend(process_json('cleaned_chats.json'))

# Add documents to the vector store
astra_vector_store.add_documents(docs)
print(f"Inserted {len(docs)} documents.")

# Create a vector store index wrapper
astra_vector_index = VectorStoreIndexWrapper(vectorstore=astra_vector_store)

print("Vector index created successfully.")
# Out:
# Inserted 5641 documents.
# Vector index created successfully.

# %%
import datetime
import warnings
from IPython.display import display, HTML
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
import logging


# Filter out specific warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
logging.getLogger('cassandra.protocol').setLevel(logging.ERROR)


# Memory setup
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

# Create the Conversational Retrieval Chain (RAG setup)
qa_chain = ConversationalRetrievalChain.from_llm(
    llm=llm,
    retriever=astra_vector_store.as_retriever(search_kwargs={"k": 3}),
    memory=memory
)

def format_message(role, content):
    """Formats the message with HTML for better display in Colab."""
    color = "#4a76a8" if role == "Bot" else "#6c757d"
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    return f"""
    <div style="margin-bottom: 10px; padding: 10px; border-radius: 5px; background-color: {color}; color: white;">
        <strong>{role}</strong> - {timestamp}<br>
        {content}
    </div>
    """

def chat_with_rag():
    print("Hi, how are you feeling today?, You can type 'exit' or 'thankyou' to end the conversation.")

    while True:
        user_input = input("\nYou: ")

        if user_input.lower() in ['exit', 'thankyou']:
            display(HTML(format_message("Bot", "Goodbye! Have a great day!")))
            break

        if not user_input.strip():
            display(HTML(format_message("Bot", "Please enter a valid question or command.")))
            continue

        try:
            result = qa_chain.invoke({"question": user_input})
            # display(HTML(format_message("You", user_input)))
            display(HTML(format_message("Bot", result['answer'])))
        except Exception as e:
            error_message = f"Oops! Something went wrong. Please try again.\nError: {str(e)}"
            display(HTML(format_message("Bot", error_message)))

if __name__ == "__main__":
    chat_with_rag()
# Out:
# Hi, how are you feeling today?, You can type 'exit' or 'thankyou' to end the conversation.
# You:  i am feeling low
#     <div style="margin-bottom: 10px; padding: 10px; border-radius: 5px; background-color: #4a76a8; color: white;">
#         <strong>Bot</strong> - 2025-05-09 18:18:00<br>
#         I'm so sorry to hear that you're feeling low. It can be really tough to deal with feelings of emptiness, laziness, and numbness. It sounds like you might be experiencing some symptoms of depression.
#
# From what I understand, it's possible that you're feeling this way because you're feeling overwhelmed and need some time to rest and recharge. It's like your mind and body are saying, "Hey, slow down, we need a break!"
#
# If that's the case, it might be helpful to take some time for yourself, do things that bring you comfort and relaxation, and prioritize your self-care. This could include things like taking a warm bath, reading a book, or spending time in nature.
#
# It's also important to remember that you're not alone in this feeling. Many people experience depression and other mental health challenges, and there is help available. If you're feeling like you need support, consider reaching out to a trusted friend, family member, or mental health professional.
#
# Remember to be kind to yourself and try not to be too hard on yourself. You're doing the best you can, and that's something to be proud of.
#     </div>
# You:  thankyou
#     <div style="margin-bottom: 10px; padding: 10px; border-radius: 5px; background-color: #4a76a8; color: white;">
#         <strong>Bot</strong> - 2025-05-09 18:18:05<br>
#         Goodbye! Have a great day!
#     </div>
